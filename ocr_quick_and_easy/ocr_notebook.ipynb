# %%
from ocr.ocr import OCR
from ocr.plotter import Plotter
import matplotlib.pyplot as plt

# %%
    ocrko = OCR()
    plotter = Plotter()
# Out:
# Datasets/dataset/v.bmp
# Datasets/dataset/r.bmp
# Datasets/dataset/g.bmp
# Datasets/dataset/m.bmp
# Datasets/dataset/h.bmp
# Datasets/dataset/y.bmp
# Datasets/dataset/u.bmp
# Datasets/dataset/p.bmp
# Datasets/dataset/l.bmp
# Datasets/dataset/c.bmp
# Datasets/dataset/i.bmp
# Datasets/dataset/o.bmp
# Datasets/dataset/w.bmp
# Datasets/dataset/e.bmp
# Datasets/dataset/j.bmp
# Datasets/dataset/f.bmp
# Datasets/dataset/b.bmp
# Datasets/dataset/x.bmp
# Datasets/dataset/t.bmp
# Datasets/dataset/s.bmp
# Datasets/dataset/k.bmp
# Datasets/dataset/d.bmp
# Datasets/dataset/n.bmp
# Datasets/dataset/z.bmp
# Datasets/dataset/a.bmp
# Datasets/dataset/q.bmp

# %%
    ocrko.bruteforce()
    plotter.show()
# Out:
# [[13]
#  [11]
#  [13]
#  [ 3]
#  [ 3]
#  [ 8]
#  [ 3]
#  [ 1]
#  [ 3]
#  [12]
#  [15]
#  [11]
#  [15]
#  [ 3]
#  [ 1]
#  [ 5]
#  [ 8]
#  [ 9]
#  [ 9]
#  [14]
#  [ 2]
#  [10]
#  [ 8]
#  [11]
#  [ 1]
#  [ 4]
#  [ 3]
#  [14]
#  [13]
#  [ 8]
#  [ 2]
#  [ 2]
#  [ 6]
#  [ 2]
#  [11]
#  [15]
#  [ 6]
#  [ 8]
#  [14]
#  [ 4]
#  [11]
#  [ 9]
#  [13]
#  [10]
#  [14]
#  [ 2]
#  [15]
#  [13]
#  [ 4]
#  [11]
#  [ 6]
#  [ 2]
#  [10]
#  [ 7]
#  [15]
#  [ 5]
#  [ 9]
#  [ 5]
#  [ 3]
#  [13]
#  [ 9]
#  [12]
#  [ 1]
#  [ 5]
#  [ 8]
#  [ 1]
#  [ 7]
#  [14]
#  [ 5]
#  [13]
#  [10]
#  [ 4]
#  [ 6]
#  [ 1]
#  [12]
#  [ 5]
#  [13]
#  [12]
#  [ 3]
#  [15]
#  [ 2]
#  [ 2]
#  [ 1]
#  [12]
#  [ 7]
#  [10]
#  [10]
#  [ 3]
#  [ 7]
#  [ 6]
#  [ 5]
#  [ 4]
#  [ 2]
#  [12]
#  [ 4]
#  [ 8]
#  [ 6]
#  [14]
#  [12]
#  [15]
#  [10]
#  [ 3]
#  [ 4]
#  [12]
#  [10]
#  [14]
#  [ 1]
#  [ 6]
#  [10]
#  [11]
#  [ 9]
#  [15]
#  [13]
#  [ 3]
#  [ 7]
#  [11]
#  [12]
#  [10]
#  [10]
#  [ 6]
#  [ 3]
#  [ 5]
#  [ 1]
#  [ 6]
#  [ 7]
# ...

# %%
plt.plot([1, 2, 1, 5, 4, -20])
plt.show()
