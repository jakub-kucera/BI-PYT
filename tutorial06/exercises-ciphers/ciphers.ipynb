# %% [markdown]
# # Procvičování - šifry

# %%
# Vynucení kontroly souladu s PEP8
# !pip install pycodestyle pycodestyle_magic
# %load_ext pycodestyle_magic
# %pycodestyle_on
# Out:
# Requirement already satisfied: pycodestyle in /home/lukany/.pyenv/versions/3.8.8/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: pycodestyle_magic in /home/lukany/.pyenv/versions/3.8.8/lib/python3.8/site-packages (0.5)

# %% [markdown]
# ### 1. Napište program pro Césarovu šifru. Tato šifra je založena na posouvání písmen o 3 pozice v abecedě (tj. a→d, m→p, z→c). Program by měl obsahovat funkce jak pro zašifrování, tak pro dešifrování takové šifry. Tyto funkce by měly brát řetězec a vrátit jeho zašifrovanou/dešifrovanou podobu.
#
# **Hint:** Možná by se vám docela mohl hodit modul `string`, obsahuje totiž takové zajímavé „konstanty“ jako `string.ascii_uppercase` a podobné.

# %%
import string

ring = string.ascii_uppercase


def cipher3(text):
    """Zašifruj zadaný ASCII-text."""

    txt = ''
    key = ring[3:] + ring[:3]
    for char in text.upper():
        if char in key:
            txt += key[ring.index(char)]
        else:
            txt += char

    return txt


def decipher3(text):
    """Odšifruj zadaný ASCII-text."""

    txt = ''
    key = ring[3:] + ring[:3]
    for char in text.upper():
        if char in key:
            txt += ring[key.index(char)]
        else:
            txt += char

    return txt

# %%
import string

ring = string.ascii_uppercase
ring_len = len(ring)


def cipher3(text):
    """Zašifruj zadaný ASCII-text."""

    txt = ''
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) + 3) % ring_len]
        else:
            txt += char

    return txt


def decipher3(text):
    """Odšifruj zadaný ASCII-text."""

    txt = ''
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) - 3) % ring_len]
        else:
            txt += char

    return txt

# %%
# test
txt = cipher3('Ahoj, jak to jde? Z')
print(txt)
print(decipher3(txt))
# Out:
# DKRM, MDN WR MGH? C
# AHOJ, JAK TO JDE? Z

# %% [markdown]
# ### 2.  Upravte předchozí program, aby umožňoval posouvání písmen i o jiné hodnoty než 3. (Zvolený krok posunu se dá označit písmenem na příslušném místě, text podle původní Césarovy šifry je pak v tomto označení zašifrován písmenem d.)

# %%
import string

ring = string.ascii_uppercase


def cipherX(text, shift):
    """Zašifruj zadaný ASCII-text uvedeným posunem."""

    txt = ''
    key = ring[shift:] + ring[:shift]
    for char in text.upper():
        if char in key:
            txt += key[ring.index(char)]
        else:
            txt += char

    return txt


def decipherX(text, shift):
    """Odšifruj zadaný ASCII-text uvedeným posunem."""

    txt = ''
    key = ring[shift:] + ring[:shift]
    for char in text.upper():
        if char in key:
            txt += ring[key.index(char)]
        else:
            txt += char

    return txt

# %%
import string

ring = string.ascii_uppercase
ring_len = len(ring)


def cipherX(text, shift):
    """Zašifruj zadaný ASCII-text uvedeným posunem."""

    txt = ''
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) + shift) % ring_len]
        else:
            txt += char

    return txt


def decipherX(text, shift):
    """Odšifruj zadaný ASCII-text uvedeným posunem."""

    txt = ''
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) - shift) % ring_len]
        else:
            txt += char

    return txt

# %%
# test
txt = cipherX('Ahoj, jak to jde? Z', -1)
print(txt)
print(decipherX(txt, -1))
# Out:
# ZGNI, IZJ SN ICD? Y
# AHOJ, JAK TO JDE? Z

# %% [markdown]
# ### 3. Použijte funkce z předchozího cvičení pro zjištění posuvu (a tím pádem i rozšifrování) následujícího zašifrovaného textu, a to hrubou silou (prostě automaticky vyzkoušejte všechny možné posuny a vyberte ten správný).

# %%
text = (
    'LYJUZJU DQ IJHQDAQSX FUDJQNVHYUDTI.UK.'
    ' IJHQDAO ZIEK LUDELQDO LIUC VEJEQFQHQJKC'
    ' FUDJQN Q TYWYJQBDYC PHSQTBELAQC IQCIKDW.'
)

# %%
for posun in range(ring_len):
    print('\n', posun)
    print('\t', decipherX(text, posun))
# Out:
#  0
# 	 LYJUZJU DQ IJHQDAQSX FUDJQNVHYUDTI.UK. IJHQDAO ZIEK LUDELQDO LIUC VEJEQFQHQJKC FUDJQN Q TYWYJQBDYC PHSQTBELAQC IQCIKDW.
#
#  1
# 	 KXITYIT CP HIGPCZPRW ETCIPMUGXTCSH.TJ. HIGPCZN YHDJ KTCDKPCN KHTB UDIDPEPGPIJB ETCIPM P SXVXIPACXB OGRPSADKZPB HPBHJCV.
#
#  2
# 	 JWHSXHS BO GHFOBYOQV DSBHOLTFWSBRG.SI. GHFOBYM XGCI JSBCJOBM JGSA TCHCODOFOHIA DSBHOL O RWUWHOZBWA NFQORZCJYOA GOAGIBU.
#
#  3
# 	 IVGRWGR AN FGENAXNPU CRAGNKSEVRAQF.RH. FGENAXL WFBH IRABINAL IFRZ SBGBNCNENGHZ CRAGNK N QVTVGNYAVZ MEPNQYBIXNZ FNZFHAT.
#
#  4
# 	 HUFQVFQ ZM EFDMZWMOT BQZFMJRDUQZPE.QG. EFDMZWK VEAG HQZAHMZK HEQY RAFAMBMDMFGY BQZFMJ M PUSUFMXZUY LDOMPXAHWMY EMYEGZS.
#
#  5
# 	 GTEPUEP YL DECLYVLNS APYELIQCTPYOD.PF. DECLYVJ UDZF GPYZGLYJ GDPX QZEZLALCLEFX APYELI L OTRTELWYTX KCNLOWZGVLX DLXDFYR.
#
#  6
# 	 FSDOTDO XK CDBKXUKMR ZOXDKHPBSOXNC.OE. CDBKXUI TCYE FOXYFKXI FCOW PYDYKZKBKDEW ZOXDKH K NSQSDKVXSW JBMKNVYFUKW CKWCEXQ.
#
#  7
# 	 ERCNSCN WJ BCAJWTJLQ YNWCJGOARNWMB.ND. BCAJWTH SBXD ENWXEJWH EBNV OXCXJYJAJCDV YNWCJG J MRPRCJUWRV IALJMUXETJV BJVBDWP.
# 	 REPAFPA JW OPNWJGWYD LAJPWTBNEAJZO.AQ. OPNWJGU FOKQ RAJKRWJU ROAI BKPKWLWNWPQI LAJPWT W ZECEPWHJEI VNYWZHKRGWI OWIOQJC.
#
#  21
# 	 QDOZEOZ IV NOMVIFVXC KZIOVSAMDZIYN.ZP. NOMVIFT ENJP QZIJQVIT QNZH AJOJVKVMVOPH KZIOVS V YDBDOVGIDH UMXVYGJQFVH NVHNPIB.
#
#  22
# 	 PCNYDNY HU MNLUHEUWB JYHNURZLCYHXM.YO. MNLUHES DMIO PYHIPUHS PMYG ZINIUJULUNOG JYHNUR U XCACNUFHCG TLWUXFIPEUG MUGMOHA.
#
#  23
# 	 OBMXCMX GT LMKTGDTVA IXGMTQYKBXGWL.XN. LMKTGDR CLHN OXGHOTGR OLXF YHMHTITKTMNF IXGMTQ T WBZBMTEGBF SKVTWEHODTF LTFLNGZ.
#
#  24
# 	 NALWBLW FS KLJSFCSUZ HWFLSPXJAWFVK.WM. KLJSFCQ BKGM NWFGNSFQ NKWE XGLGSHSJSLME HWFLSP S VAYALSDFAE RJUSVDGNCSE KSEKMFY.
#
#  25
# 	 MZKVAKV ER JKIREBRTY GVEKROWIZVEUJ.VL. JKIREBP AJFL MVEFMREP MJVD WFKFRGRIRKLD GVEKRO R UZXZKRCEZD QITRUCFMBRD JRDJLEX.

# %% [markdown]
# ### 4. Napište program pro Vigenèrovu šifru. Podobně jako u Césarovy šifry dochází k posunu písmen, ale tento posun není určen pouze jedním vybraným číslem (a tedy vlastně písmenem), nýbrž celým klíčovým slovem (heslem) nebo dokonce delším textem. Po sobě jdoucí písmena původní zprávy jsou tedy vlastně šifrována Césarovými šiframi s různým krokem.
#
# **Příklad**:
#
# * zpráva:	PYTHON JE FAJN
# * heslo:	HESLOH ES LOHE
# * výstup:	WCLSCU NW QOQR
#
# **Zajmavost**: Podle Wikipedie však Blaise de Vigenèr přišel s touto šifrou v roce 1586, tedy až třicet tři let potom, co Giovan Battista Bellaso tímto způsobem zobecnil původní dvouabecední šifru Leona Battisty Albertiho dokonce už z roku 1467.

# %%
import string

ring = string.ascii_uppercase
ring_len = len(ring)


def cipher_vigener(text, key):
    """Zašifruj zadaný ASCII-text uvedeným posunem."""
    keylen = len(key)
    keyarr = [ring.index(x) for x in key.upper()]
    txt = ''
    i = 0
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) + keyarr[i % keylen]) % ring_len]
            i += 1
        else:
            txt += char
    return txt


def decipher_vigener(text, key):
    """Odšifruj zadaný ASCII-text uvedeným posunem."""
    keylen = len(key)
    keyarr = [ring.index(x) for x in key.upper()]
    txt = ''
    i = 0
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) - keyarr[i % keylen]) % ring_len]
            i += 1
        else:
            txt += char
    return txt

# %%
txt = cipher_vigener('Python je fajn.', 'heslo')
print(txt)
print(decipher_vigener(txt, 'heslo'))
# Out:
# WCLSCU NW QOQR.
# PYTHON JE FAJN.

# %% [markdown]
# ### 5. Dostal se vám do rukou zakódovaný text ze souboru `tajne.txt` zašifrovaný Vigènerovou šifrou. Navíc víte, že se jedná o český text, a to dokonce beze všech nabodeníček (tedy je v ASCII), a že jako heslo bylo použito jedno ze slov ze seznam `hesla.txt`, ale netušíte které, a že navíc zakódována byla pouze písmena (tedy interpunkce a mezery se přeskakují) a ještě jenom v jedné velikosti (tedy nerozlišuje se mezi malými a velkými písmeny). Vaším úkolem je zjistit heslo použité k zašifrování textu a text rozluštit.

# %%
import string

ring = string.ascii_uppercase
ring_len = len(ring)


def decipher(text, key):
    """Odšifruj zadaný ASCII-text uvedeným posunem."""
    keylen = len(key)
    keyarr = [ring.index(x) for x in key.upper()]
    txt = ''
    i = 0
    for char in text.upper():
        if char in ring:
            txt += ring[(ring.index(char) - keyarr[i % keylen]) % ring_len]
            i += 1
        else:
            txt += char
    return txt


# hledani

utajeny = ''
with open('tajne.txt', encoding='utf-8', mode='r') as f_in:
    utajeny = f_in.read()

slova = set()
with open('hesla.txt', encoding='utf-8', mode='r') as f_in:
    for line in f_in:
        slovo = line.strip('\n').upper()
        slova.add(slovo)
print(len(slova))
print()

bad = open('bad.log', mode='w', encoding='utf-8')
count = 0
hesla = []
for i, heslo in enumerate(slova):
    count += 1
    if count == 1000:
        print('> ', i)
        count = 0
    try:
        text = decipher(utajeny, heslo)
    except ValueError:
        # print(heslo)
        bad.write(heslo + '\n')
        bad.flush()
        print('! ValueError:', heslo)
        continue
    # print(text)
    kandidat = sorted(text.split(), key=len)[-1]
    # print(kandidat)
    if kandidat in slova:
        print(heslo)
        hesla.append(heslo)
        print(text)
        print()
bad.close()
# Out:
# 260000
#
# >  999
# >  1999
# >  2999
# >  3999
# >  4999
# >  5999
# >  6999
# >  7999
# >  8999
# >  9999
# >  10999
# >  11999
# >  12999
# >  13999
# >  14999
# >  15999
# >  16999
# >  17999
# >  18999
# >  19999
# >  20999
# >  21999
# >  22999
# >  23999
# TERAPEUTKY
# JAK SE TEDY DELA FILM
#
# ALE I KDYZ SI ODMYSLIME TO VSECHNO TECHNICKE, CEHO JE PRI TOCENI FILMU TREBA, SHLEDAME PO DELSIM OKOUNENI A DIVENI, ZE SE FILM VLASTNE DELA JINAK, NEZ JAK BY SI PREDSTAVOVAL DIVAK V BIOGRAFU. NAPRIKLAD DIVAK VERI, ZE HERCI VE FILMU HRAJI JAKYSI DEJ. TO JE TA NEJVETSI FILMOVA ILUZE. VE SKUTECNOSTI HERCI HRAJI JENOM JEDNOTLIVE ZABERY, DOKONCE V LIBOVOLNEM PORADKU; A PREDEPSANY SOUVISLY DEJ SE Z TOHO UDELA AZ NA KONEC, PRI SESTRIHU. FILMOVY HEREC NENI NOSITELEM DEJE, NYBRZ JENOM PREDSTAVITELEM FIGURY; NOSITELEM DEJE JE VLASTNE FILMOVY REZISER. FILMOVY HEREC NEODRIKAVA DIALOGY, NYBRZ JEN KOUSKY DIALOGU, KTERE SE TEPRVE DODATECNE SLEPI DOHROMADY. MALOKDY REKNE NA JEDEN ZABER VIC NEZ JEDNU VETU. NIKDY SE NEMUZE VZIT DO ROLE, NYBRZ JEN DO FIGURY, ABY JI "UDRZEL" V TECH NEKOLIKA DESITKACH NEBO STECH JEDNOTLIVYCH A NESOUVISLYCH PULMINUTOVYCH NEBO MINUTOVYCH ZABERU. HERCOVA HRA VE FILMU JE JAKO KAMINKY, ZE KTERYCH TEPRVE REZISER SKLADA SOUVISLOU MOZAIKU.
# "TAK, SLECNO, TED MUSITE VZPLANOUT A RICI NE, NIKDY," REKNE REZISER.
# A SLECNA VZPLANE A VYKRIKNE: "NE, NIKDY!"
# "STOP," REKNE REZISER. "DOBRE. TAK TED SI TO OSVETLIME A SJEDEME TO."
# ZA PUL HODINY TO BUDE SJETO. "A TED, SLECNO, MLCKY ZAPLACETE," DI REZISER.
# A SLECNA MLCKY ZAPLACE.
# "STOP," PRAVI REZISER. "TAK OSVETLIT A JEDEME."
# "CISLO STO DEVADESAT SEDM," VYKRIKNE MLADIK VE SVETRU A PLACNE JI PRED NOSEM KLAPKOU. SLECNA MLCKY ZAPLACE A APARAT ZAVRCI.
# "STOP," ZVOLA REZISER. "DOBRE JE TO!"
# A JEDE SE DAL. BUDE SE TREBA TOCIT SCENA, VE KTERE SLECNA POPRVE SPATRI TOHO, PRO NEHOZ V CISLE STO DEVADESAT SEDM MLCKY ZAPLAKALA.
# "DNES NAM TO SLO," LIBUJE SI REZISER, KDYZ HO VECER DIV NEVYNASEJI Z ATELIERU NA NOSITKACH, VYCERPANEHO UNAVOU. "NATOCILI JSME DVACET ZABERU!"
# TECH DVACET ZABERU PAK NA PLATNE PREBEHNE STEZI ZA DESET MINUT; A TO JESTE SE Z NICH VETSINA NEKDY VYSTRIHNE A ZAHODI. TAKOVA JE TO PRACE.
# I VZDEJTEZ SE ILUZE, ZE VASE MILOVANA FILMOVA HVEZDA NEJAK PROZIVALA TY POLIBKY, SLZY A JIHNOUCI POHLEDY, KTERYMI VAS DOJIMA NA PLATNE. KDEPAK. TO BYLA JEN CISLA. ALE NECHCETE-LI SE TE ILUZE VZDAT, TAKY DOBRE; PROC BYSTE SE MELI DIVAT ZROVNA NA FILM KRITICTEJI NEZ NA JINE LIDSKE KONANI!
#
# >  24999
# >  25999
# >  26999
# >  27999
# >  28999
# >  29999
# >  30999
# >  31999
# >  32999
# >  33999
# >  34999
# >  35999
# >  36999
# >  37999
# >  38999
# >  39999
# >  40999
# >  41999
# >  42999
# >  43999
# >  44999
# >  45999
# >  46999
# >  47999
# >  48999
# >  49999
# >  50999
# >  51999
# >  52999
# >  53999
# >  54999
# >  55999
# >  56999
# >  57999
# >  58999
# >  59999
# >  60999
# >  61999
# >  62999
# ALE I KDYZ SI ODMYSLIME TO VSECHNO TECHNICKE, CEHO JE PRI TOCENI FILMU TREBA, SHLEDAME PO DELSIM OKOUNENI A DIVENI, ZE SE FILM VLASTNE DELA JINAK, NEZ JAK BY SI PREDSTAVOVAL DIVAK V BIOGRAFU. NAPRIKLAD DIVAK VERI, ZE HERCI VE FILMU HRAJI JAKYSI DEJ. TO JE TA NEJVETSI FILMOVA ILUZE. VE SKUTECNOSTI HERCI HRAJI JENOM JEDNOTLIVE ZABERY, DOKONCE V LIBOVOLNEM PORADKU; A PREDEPSANY SOUVISLY DEJ SE Z TOHO UDELA AZ NA KONEC, PRI SESTRIHU. FILMOVY HEREC NENI NOSITELEM DEJE, NYBRZ JENOM PREDSTAVITELEM FIGURY; NOSITELEM DEJE JE VLASTNE FILMOVY REZISER. FILMOVY HEREC NEODRIKAVA DIALOGY, NYBRZ JEN KOUSKY DIALOGU, KTERE SE TEPRVE DODATECNE SLEPI DOHROMADY. MALOKDY REKNE NA JEDEN ZABER VIC NEZ JEDNU VETU. NIKDY SE NEMUZE VZIT DO ROLE, NYBRZ JEN DO FIGURY, ABY JI "UDRZEL" V TECH NEKOLIKA DESITKACH NEBO STECH JEDNOTLIVYCH A NESOUVISLYCH PULMINUTOVYCH NEBO MINUTOVYCH ZABERU. HERCOVA HRA VE FILMU JE JAKO KAMINKY, ZE KTERYCH TEPRVE REZISER SKLADA SOUVISLOU MOZAIKU.
# "TAK, SLECNO, TED MUSITE VZPLANOUT A RICI NE, NIKDY," REKNE REZISER.
# A SLECNA VZPLANE A VYKRIKNE: "NE, NIKDY!"
# "STOP," REKNE REZISER. "DOBRE. TAK TED SI TO OSVETLIME A SJEDEME TO."
# ZA PUL HODINY TO BUDE SJETO. "A TED, SLECNO, MLCKY ZAPLACETE," DI REZISER.
# A SLECNA MLCKY ZAPLACE.
# "STOP," PRAVI REZISER. "TAK OSVETLIT A JEDEME."
# "CISLO STO DEVADESAT SEDM," VYKRIKNE MLADIK VE SVETRU A PLACNE JI PRED NOSEM KLAPKOU. SLECNA MLCKY ZAPLACE A APARAT ZAVRCI.
# "STOP," ZVOLA REZISER. "DOBRE JE TO!"
# A JEDE SE DAL. BUDE SE TREBA TOCIT SCENA, VE KTERE SLECNA POPRVE SPATRI TOHO, PRO NEHOZ V CISLE STO DEVADESAT SEDM MLCKY ZAPLAKALA.
# "DNES NAM TO SLO," LIBUJE SI REZISER, KDYZ HO VECER DIV NEVYNASEJI Z ATELIERU NA NOSITKACH, VYCERPANEHO UNAVOU. "NATOCILI JSME DVACET ZABERU!"
# TECH DVACET ZABERU PAK NA PLATNE PREBEHNE STEZI ZA DESET MINUT; A TO JESTE SE Z NICH VETSINA NEKDY VYSTRIHNE A ZAHODI. TAKOVA JE TO PRACE.
# I VZDEJTEZ SE ILUZE, ZE VASE MILOVANA FILMOVA HVEZDA NEJAK PROZIVALA TY POLIBKY, SLZY A JIHNOUCI POHLEDY, KTERYMI VAS DOJIMA NA PLATNE. KDEPAK. TO BYLA JEN CISLA. ALE NECHCETE-LI SE TE ILUZE VZDAT, TAKY DOBRE; PROC BYSTE SE MELI DIVAT ZROVNA NA FILM KRITICTEJI NEZ NA JINE LIDSKE KONANI!
